# %%
import this

# %%
import numpy as np

# %%
import pandas as pd

# %%
cd ~/git/bootcamp
# Out:
# /Users/ladybug/git/bootcamp

# %%
# !head data/gfmt_sleep.csv
# Out:
# ﻿participant number,gender,age,correct hit percentage,correct reject percentage,percent correct,confidence when correct hit,confidence incorrect hit,confidence correct reject,confidence incorrect reject,confidence when correct,confidence when incorrect,sci,psqi,ess
# 8,f,39,65,80,72.5,91,90,93,83.5,93,90,9,13,2
# 16,m,42,90,90,90,75.5,55.5,70.5,50,75,50,4,11,7
# 18,f,31,90,95,92.5,89.5,90,86,81,89,88,10,9,3
# 22,f,35,100,75,87.5,89.5,*,71,80,88,80,13,8,20
# 27,f,74,60,65,62.5,68.5,49,61,49,65,49,13,9,12
# 28,f,61,80,20,50,71,63,31,72.5,64.5,70.5,15,14,2
# 30,m,32,90,75,82.5,67,56.5,66,65,66,64,16,9,3
# 33,m,62,45,90,67.5,54,37,65,81.5,62,61,14,9,9
# 34,f,33,80,100,90,70.5,76.5,64.5,*,68,76.5,14,12,10

# %%
#save file as df (data frame)
df = pd.read_csv('data/gfmt_sleep.csv')

# %%
#data method head without argument prints first 5 lines
df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#   confidence incorrect hit  confidence correct reject  \
# 0                       90                       93.0
# ...

# %%
df.loc[4, 'percent correct']
# Out:
# 62.5

# %%
#print percent correct for participant number 22
df.loc[df['participant number'] == 22, 'percent correct']
# Out:
# 3    87.5
# Name: percent correct, dtype: float64

# %%
#print whole row for participant number 22
df.loc[df['participant number'] == 22, :]
# Out:
#    participant number gender  age  correct hit percentage  \
# 3                  22      f   35                     100
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 3                         75             87.5                         89.5
#
#   confidence incorrect hit  confidence correct reject  \
# 3                        *                       71.0
#
#   confidence incorrect reject  confidence when correct  \
# 3                          80                     88.0
#
#   confidence when incorrect  sci  psqi  ess
# 3                        80   13     8   20

# %%
#string together indices to locate all female participants < 21

df.loc[(df['age']<21) & (df['gender'] == 'f'), :]
# Out:
#     participant number gender  age  correct hit percentage  \
# 27                   3      f   16                      70
# 29                   5      f   18                      90
# 66                  58      f   16                      85
# 79                  72      f   18                      80
# 88                  85      f   18                      85
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 27                         80             75.0                         70.0
# 29                        100             95.0                         76.5
# 66                         85             85.0                         55.0
# 79                         75             77.5                         67.5
# 88                         85             85.0                         93.0
#
#    confidence incorrect hit  confidence correct reject  \
# 27                       57                       54.0
# ...

# %%
#store as df_female_minor
df_female_minor = df.loc[(df['age']<21) & (df['gender'] == 'f'), :]

df_female_minor
# Out:
#     participant number gender  age  correct hit percentage  \
# 27                   3      f   16                      70
# 29                   5      f   18                      90
# 66                  58      f   16                      85
# 79                  72      f   18                      80
# 88                  85      f   18                      85
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 27                         80             75.0                         70.0
# 29                        100             95.0                         76.5
# 66                         85             85.0                         55.0
# 79                         75             77.5                         67.5
# 88                         85             85.0                         93.0
#
#    confidence incorrect hit  confidence correct reject  \
# 27                       57                       54.0
# ...

# %%
#store indices to avoid unwieldy coding
inds = (df['age'] > 30) & (df['gender'] == 'f') & (df['percent correct'] > 85)

df.loc[inds, :]
# Out:
#     participant number gender  age  correct hit percentage  \
# 2                   18      f   31                      90
# 3                   22      f   35                     100
# 8                   34      f   33                      80
# 11                  41      f   36                      90
# 31                   7      f   38                      90
# 40                  19      f   45                     100
# 45                  25      f   36                     100
# 47                  29      f   43                      90
# 55                  43      f   31                      85
# 57                  45      f   42                      90
# 69                  61      f   34                      90
# 70                  62      f   42                     100
# 72                  64      f   69                      95
# 73                  65      f   31                     100
# 74                  66      f   44                      90
# ...

# %%
#new column called insomnia based on existing data in column sci
df['insomnia'] = df['sci'] <= 16

df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#   confidence incorrect hit  confidence correct reject  \
# 0                       90                       93.0
# ...

# %%
#summary statistics just for insomniacs
df.loc[df['insomnia'] == True, :].describe()
# Out:
#        participant number        age  correct hit percentage  \
# count           25.000000  25.000000               25.000000
# mean            53.400000  40.320000               82.000000
# std             29.219001  12.915495               18.314384
# min              8.000000  24.000000               40.000000
# 25%             30.000000  31.000000               70.000000
# 50%             46.000000  39.000000               90.000000
# 75%             78.000000  44.000000              100.000000
# max            101.000000  74.000000              100.000000
#
#        correct reject percentage  percent correct  \
# count                   25.00000        25.000000
# mean                    70.20000        76.100000
# std                     23.33988        13.347909
# min                     20.00000        45.000000
# 25%                     55.00000        70.000000
# 50%                     75.00000        75.000000
# 75%                     90.00000        87.500000
# ...

# %%
df
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#   confidence incorrect hit  confidence correct reject  \
# 0                       90                       93.0
# ...

# %%
df['insomnia'] = df['sci'] <= 16

df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#   confidence incorrect hit  confidence correct reject  \
# 0                       90                       93.0
# ...

# %%
#split
grouped = df.groupby('insomnia')

# %%
#apply, combine
grouped.median()
# Out:
#           participant number  age  correct hit percentage  \
# insomnia
# False                     54   36                      90
# True                      46   39                      90
#
#           correct reject percentage  percent correct  \
# insomnia
# False                            80             85.0
# True                             75             75.0
#
#           confidence when correct hit  confidence correct reject  \
# insomnia
# False                            74.5                       71.5
# True                             76.5                       71.0
#
#           confidence when correct  sci  psqi  ess
# insomnia
# False                        75.0   26     4    6
# True                         77.0   14     9    7

# %%
#index resetting
grouped.median().reset_index()
# Out:
#    insomnia  participant number  age  correct hit percentage  \
# 0     False                  54   36                      90
# 1      True                  46   39                      90
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             85.0                         74.5
# 1                         75             75.0                         76.5
#
#    confidence correct reject  confidence when correct  sci  psqi  ess
# 0                       71.5                     75.0   26     4    6
# 1                       71.0                     77.0   14     9    7

# %%
def coeff_of_var(data):
    return np.std(data) / np.mean(data)

# %%
grouped.agg(coeff_of_var)
# Out:
#           participant number       age  correct hit percentage  \
# insomnia
# False               0.586191  0.384262                0.166784
# True                0.536117  0.313853                0.218834
#
#           correct reject percentage  percent correct  \
# insomnia
# False                      0.184061         0.138785
# True                       0.325760         0.171856
#
#           confidence when correct hit  confidence correct reject  \
# insomnia
# False                        0.195978                   0.204312
# True                         0.156219                   0.222827
#
#           confidence when correct       sci      psqi       ess
# insomnia
# False                    0.187304  0.175245  0.577869  0.571566
# True                     0.160061  0.381907  0.299741  0.681514

# %%
df['rank grouped by insomnia'] = (grouped['percent correct'].rank(method='first'))

df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#   confidence incorrect hit  confidence correct reject  \
# 0                       90                       93.0
# ...

# %%
#sort the values by insomnia, then by percent correct
df_sorted = df.sort_values(by=['insomnia', 'percent correct'])

#without loc, this returns the listed columns
df_sorted[['insomnia', 'percent correct', 'rank grouped by insomnia']]
# Out:
#      insomnia  percent correct  rank grouped by insomnia
# 81      False             40.0                       1.0
# 94      False             55.0                       2.0
# 39      False             57.5                       3.0
# 76      False             60.0                       4.0
# 96      False             60.0                       5.0
# 86      False             62.5                       6.0
# 101     False             62.5                       7.0
# 41      False             65.0                       8.0
# 28      False             67.5                       9.0
# 50      False             67.5                      10.0
# 34      False             70.0                      11.0
# 100     False             70.0                      12.0
# 25      False             72.5                      13.0
# 52      False             72.5                      14.0
# 53      False             72.5                      15.0
# ...
